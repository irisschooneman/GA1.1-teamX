# %%
def add(a, b):
    return a + b

# %%
print(add(2, 3))
print(add(10, 5))
print(add(-2, 7))

# %%
def sumlist(values):
    return sum(values)
values1 = [1, 2, 3, 4, 5]
values2 = [1, 10, 3, 4, 5]
print(sumlist(values1))
print(sumlist(values2))
# Out:
# 15
# 23
